# %% [markdown]
# #Khurram Saeed
# #20015020018

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from google.colab import drive
drive.mount('/content/gdrive')
path = '/content/gdrive/MyDrive/UniversityWork/7semester/DataScience/Task1/BigMart/test.csv'

df = pd.read_csv(path)

data_types = df.dtypes
print(data_types)
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).
# Item_Identifier               object
# Item_Weight                  float64
# Item_Fat_Content              object
# Item_Visibility              float64
# Item_Type                     object
# Item_MRP                     float64
# Outlet_Identifier             object
# Outlet_Establishment_Year      int64
# Outlet_Size                   object
# Outlet_Location_Type          object
# Outlet_Type                   object
# dtype: object

# %%
missing_values = df.isnull().sum()

print(missing_values)
# Out:
# Item_Identifier                 0
# Item_Weight                   976
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  1606
# Outlet_Location_Type            0
# Outlet_Type                     0
# dtype: int64

# %%
numColumbs = df.shape[1]
print(numColumbs)
# Out:
# 11

# %%
print(len(df['Item_Fat_Content'].unique()))
# Out:
# 5

# %%
print(len(df['Item_Type'].unique()))
# Out:
# 16

# %%
print(df['Item_MRP'].mean())
# Out:
# 141.02327340256994

# %%
plt.plot(df['Item_Weight'],df['Item_Type'])
plt.title('Task 1')
plt.xlabel('item weight')
plt.ylabel('item type')
# Out:
# Text(0, 0.5, 'item type')

# %%
 avg = df.groupby('Item_Type')['Item_MRP'].mean().reset_index()
 plt.plot(avg['Item_MRP'],avg['Item_Type'], marker='*', ms='10', linestyle='')
 plt.xlabel('item type')
 plt.ylabel('item MRP')
 plt.title('Item_weight vs Item type')
# Out:
# Text(0.5, 1.0, 'Item_weight vs Item type')
